# %%
ls
# Out:
# column_names.md    kc_house_data.csv

# %%
cd data
# Out:
# [Errno 2] No such file or directory: 'data'
# /Users/eldrichvergarciadoyogan/Documents/Flatiron/Projects/Phase2Project/dsc-phase-2-project/data

# %%
ls
# Out:
# column_names.md    kc_house_data.csv

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
train_test_split(df)
# Out:
# [               id        date     price  bedrooms  bathrooms  sqft_living  \
#  15492  6669070080   4/17/2015  699000.0         3       2.50         2370
#  3097   5360200054   10/2/2014  247500.0         3       2.00         1530
#  16562  5454200080   8/11/2014  968000.0         4       1.75         2630
#  11165  7338401230   8/28/2014  285000.0         3       1.75         1020
#  20213  3278603000    5/4/2015  459000.0         3       3.00         2440
#  ...           ...         ...       ...       ...        ...          ...
#  1534   5363200200    4/2/2015  932800.0         5       3.25         2980
#  4149    808300090   1/16/2015  435000.0         4       2.50         2650
#  859    1865820370  11/13/2014  166600.0         3       1.75         1150
#  6170   1727500010    1/7/2015  354000.0         3       1.75         1340
#  1645   9276200890   4/29/2015  450000.0         2       1.75         1760
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
to_drop = ['view', 'sqft_above', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sqft_basement' ]

# %%
df.drop(to_drop, axis = 1, inplace = True)

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  condition  grade  yr_built  yr_renovated  \
# ...

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    19075
# 1.0      146
# Name: waterfront, dtype: int64

# %%
df.loc[df['waterfront'].isna() == True]
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 10     1736800520    4/3/2015  662500.0         3       2.50         3560
# 23     8091400200   5/16/2014  252700.0         2       1.50         1070
# 40     5547700270   7/15/2014  625000.0         4       2.50         2570
# 55     9822700295   5/12/2014  885000.0         4       2.50         2830
# ...           ...         ...       ...       ...        ...          ...
# 21578  5087900040  10/17/2014  350000.0         4       2.75         2500
# 21582  8956200760  10/13/2014  541800.0         4       2.50         3118
# 21586   844000965   6/26/2014  224000.0         3       1.75         1500
# 21587  7852140040   8/25/2014  507250.0         3       2.50         2270
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
#
#        sqft_lot  floors  waterfront  condition  grade  yr_built  yr_renovated  \
# ...

# %%
df.loc[df['yr_renovated'].isna() == True]
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 2      5631500400   2/25/2015   180000.0         2       1.00          770
# 12      114101516   5/28/2014   310000.0         3       1.00         1430
# 23     8091400200   5/16/2014   252700.0         2       1.50         1070
# 26     1794500383   6/26/2014   937000.0         3       1.75         2450
# 28     5101402488   6/24/2014   438000.0         3       1.75         1520
# ...           ...         ...        ...       ...        ...          ...
# 21576  1931300412   4/16/2015   475000.0         3       2.25         1190
# 21577  8672200110   3/17/2015  1090000.0         5       3.75         4170
# 21579  1972201967  10/31/2014   520000.0         2       2.25         1530
# 21581   191100405   4/21/2015  1580000.0         4       3.25         3410
# 21583  7202300110   9/15/2014   810000.0         4       3.00         3990
#
# ...

# %%
plt.hist(df['price'], bins = 1000);

# %%
plt.hist(df['bedrooms'], bins = 50);

# %%
plt.hist(df['date'], bins = 200);

# %%
ax = plt.hist(df['bathrooms'], bins = 30);

# %%
plt.hist(df['sqft_living'], bins = 200);

# %%
plt.hist(df['sqft_lot'], bins = 50);

# %%
plt.hist(df['floors'], bins = 200);

# %%
plt.hist(df['waterfront'], bins = 200);
# Out:
# /Users/eldrichvergarciadoyogan/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/eldrichvergarciadoyogan/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.hist(df['condition'], bins = 200);

# %%
plt.hist(df['grade'], bins = 200);

# %%
plt.hist(df['yr_built'], bins = 200);

# %%
plt.hist(df['yr_renovated'], bins = 200);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            21597 non-null  int64
#  1   date          21597 non-null  object
#  2   price         21597 non-null  float64
#  3   bedrooms      21597 non-null  int64
#  4   bathrooms     21597 non-null  float64
#  5   sqft_living   21597 non-null  int64
#  6   sqft_lot      21597 non-null  int64
#  7   floors        21597 non-null  float64
#  8   waterfront    19221 non-null  float64
#  9   condition     21597 non-null  int64
#  10  grade         21597 non-null  int64
#  11  yr_built      21597 non-null  int64
#  12  yr_renovated  17755 non-null  float64
#  13  zipcode       21597 non-null  int64
# dtypes: float64(5), int64(8), object(1)
# memory usage: 2.3+ MB
